# %%
# importing required packages
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
import warnings
import seaborn as sns

warnings.filterwarnings('ignore')

# %%
# reading dataset from csv file and storing in df variable
df = pd.read_csv('loan.csv')
df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# 3   13.49%       339.31     C        C1  ...                NaN
# 4   12.69%        67.79     B        B5  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# 0                NaN            NaN               NaN                  0.0
# 1                NaN            NaN               NaN                  0.0
# 2                NaN            NaN               NaN                  0.0
# 3                NaN            NaN               NaN                  0.0
# 4                NaN            NaN               NaN                  0.0
#
#   tax_liens tot_hi_cred_lim total_bal_ex_mort total_bc_limit  \
# 0       0.0             NaN               NaN            NaN
# 1       0.0             NaN               NaN            NaN
# 2       0.0             NaN               NaN            NaN
# 3       0.0             NaN               NaN            NaN
# 4       0.0             NaN               NaN            NaN
#
#   total_il_high_credit_limit
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
#
# [5 rows x 111 columns]

# %%
# checking the number of records in the dataset
df.shape
# Out:
# (39717, 111)

# %%
# Settings the number of rows to display in output to few all column data
# got below code from "https://stackoverflow.com/questions/58298963/jupyter-not-showing-whole-output" url
pd.set_option('display.max_rows', 200)

# %%
# checking the datatypes of the columns in the dataset
df.dtypes
# Out:
# id                                  int64
# member_id                           int64
# loan_amnt                           int64
# funded_amnt                         int64
# funded_amnt_inv                   float64
# term                               object
# int_rate                           object
# installment                       float64
# grade                              object
# sub_grade                          object
# emp_title                          object
# emp_length                         object
# home_ownership                     object
# annual_inc                        float64
# verification_status                object
# issue_d                            object
# loan_status                        object
# pymnt_plan                         object
# url                                object
# desc                               object
# purpose                            object
# title                              object
# zip_code                           object
# addr_state                         object
# dti                               float64
# delinq_2yrs                         int64
# earliest_cr_line                   object
# inq_last_6mths                      int64
# mths_since_last_delinq            float64
# mths_since_last_record            float64
# open_acc                            int64
# pub_rec                             int64
# revol_bal                           int64
# revol_util                         object
# total_acc                           int64
# initial_list_status                object
# out_prncp                         float64
# out_prncp_inv                     float64
# total_pymnt                       float64
# total_pymnt_inv                   float64
# total_rec_prncp                   float64
# total_rec_int                     float64
# total_rec_late_fee                float64
# recoveries                        float64
# collection_recovery_fee           float64
# last_pymnt_d                       object
# last_pymnt_amnt                   float64
# next_pymnt_d                       object
# last_credit_pull_d                 object
# collections_12_mths_ex_med        float64
# mths_since_last_major_derog       float64
# policy_code                         int64
# application_type                   object
# annual_inc_joint                  float64
# dti_joint                         float64
# verification_status_joint         float64
# acc_now_delinq                      int64
# tot_coll_amt                      float64
# tot_cur_bal                       float64
# open_acc_6m                       float64
# open_il_6m                        float64
# open_il_12m                       float64
# open_il_24m                       float64
# mths_since_rcnt_il                float64
# total_bal_il                      float64
# il_util                           float64
# open_rv_12m                       float64
# open_rv_24m                       float64
# max_bal_bc                        float64
# all_util                          float64
# total_rev_hi_lim                  float64
# inq_fi                            float64
# total_cu_tl                       float64
# inq_last_12m                      float64
# acc_open_past_24mths              float64
# avg_cur_bal                       float64
# bc_open_to_buy                    float64
# bc_util                           float64
# chargeoff_within_12_mths          float64
# delinq_amnt                         int64
# mo_sin_old_il_acct                float64
# mo_sin_old_rev_tl_op              float64
# mo_sin_rcnt_rev_tl_op             float64
# mo_sin_rcnt_tl                    float64
# mort_acc                          float64
# mths_since_recent_bc              float64
# mths_since_recent_bc_dlq          float64
# mths_since_recent_inq             float64
# mths_since_recent_revol_delinq    float64
# num_accts_ever_120_pd             float64
# num_actv_bc_tl                    float64
# num_actv_rev_tl                   float64
# num_bc_sats                       float64
# num_bc_tl                         float64
# num_il_tl                         float64
# num_op_rev_tl                     float64
# num_rev_accts                     float64
# num_rev_tl_bal_gt_0               float64
# num_sats                          float64
# num_tl_120dpd_2m                  float64
# num_tl_30dpd                      float64
# num_tl_90g_dpd_24m                float64
# num_tl_op_past_12m                float64
# pct_tl_nvr_dlq                    float64
# percent_bc_gt_75                  float64
# pub_rec_bankruptcies              float64
# tax_liens                         float64
# tot_hi_cred_lim                   float64
# total_bal_ex_mort                 float64
# total_bc_limit                    float64
# total_il_high_credit_limit        float64
# dtype: object

# %% [markdown]
# # Datatype Conversions
#
# _Converting the columns data with relevant data type {e.g. converting string date to date format}_

# %%
# ID of the customer is not a numeric value to perform some operation, but a unique value to identify the customer
# So, converting id column to String type
df.id = df.id.astype(str)
df.id.describe()
# Out:
# count      39717
# unique     39717
# top       494603
# freq           1
# Name: id, dtype: object

# %%
# Member ID of the customer is not a numeric value to perform some operation, but a unique value to identify the customer membership
# So, converting member id column to String type

df.member_id = df.member_id.astype(str)
df.member_id.describe()
# Out:
# count      39717
# unique     39717
# top       929917
# freq           1
# Name: member_id, dtype: object

# %%
# Term in the dataset is available as object, where term is a interger value of number of months the loan period
# replacing the "months" with empty string and converting it to int
df.term = df.term.apply(lambda x: int(x.replace('months', '').strip()))
df.term.describe()
# Out:
# count    39717.000000
# mean        42.418007
# std         10.622815
# min         36.000000
# 25%         36.000000
# 50%         36.000000
# 75%         60.000000
# max         60.000000
# Name: term, dtype: float64

# %%
# Interest Rate on the loan is a numeric value and only contains percentage symbol in addition with the interest rate
# by removing "%" from the interest rate column, we can convert it into numberic column [float type]
# df.int_rate = df.int_rate.apply(lambda x: float(x.replace('%', '').strip()))
# df.int_rate.describe()

# %%
# converting issue_d i.e. The month which the loan was funded column type to date format
df.issue_d = pd.to_datetime(df.issue_d, format='%b-%y')
df.issue_d.describe()
# Out:
# count                   39717
# unique                     55
# top       2011-12-01 00:00:00
# freq                     2260
# first     2007-06-01 00:00:00
# last      2011-12-01 00:00:00
# Name: issue_d, dtype: object

# %%
# converting earliest_cr_line i.e. The month the borrower's earliest reported credit line was opened column type to date format
df.earliest_cr_line = pd.to_datetime(df.earliest_cr_line, format='%b-%y')
df.earliest_cr_line.describe()
# Out:
# count                   39717
# unique                    526
# top       1998-11-01 00:00:00
# freq                      370
# first     1969-02-01 00:00:00
# last      2068-12-01 00:00:00
# Name: earliest_cr_line, dtype: object

# %%
#  converting revol_util i.e. Revolving line utilization rate, or the amount of credit the borrower is using relative to all available revolving credit  column to float type by removing "%"
df.revol_util = df.revol_util.apply(lambda x: float(str(x).replace('%', '').strip()))
df.revol_util.describe()
# Out:
# count    39667.000000
# mean        48.832152
# std         28.332634
# min          0.000000
# 25%         25.400000
# 50%         49.300000
# 75%         72.400000
# max         99.900000
# Name: revol_util, dtype: float64

# %%
# converting last_pymnt_d column to date type column
df.last_pymnt_d = pd.to_datetime(df.last_pymnt_d, format='%b-%y')
df.last_pymnt_d.describe()
# Out:
# count                   39646
# unique                    101
# top       2016-05-01 00:00:00
# freq                     1256
# first     2008-01-01 00:00:00
# last      2016-05-01 00:00:00
# Name: last_pymnt_d, dtype: object

# %%
# converting next_pymnt_d column to date type column
df.next_pymnt_d = pd.to_datetime(df.next_pymnt_d, format='%b-%y')
df.next_pymnt_d.describe()
# Out:
# count                    1140
# unique                      2
# top       2016-06-01 00:00:00
# freq                     1125
# first     2016-06-01 00:00:00
# last      2016-07-01 00:00:00
# Name: next_pymnt_d, dtype: object

# %%
# converting last_credit_pull_d column to date type column
df.last_credit_pull_d = pd.to_datetime(df.last_credit_pull_d, format='%b-%y')
df.last_credit_pull_d.describe()
# Out:
# count                   39715
# unique                    106
# top       2016-05-01 00:00:00
# freq                    10308
# first     2007-05-01 00:00:00
# last      2016-05-01 00:00:00
# Name: last_credit_pull_d, dtype: object

# %% [markdown]
# # Data cleaning
# _fixing the issues in the column data_

# %%
# As per Data Dictionary, id of a customer should be unique
df.id.is_unique
# Out:
# True

# %%
# As per Data Dictionary, member id of a customer should be unique
# checking member id column is unique by checking number of records [count] and unique values [unique] are same/equal
df.member_id.is_unique
# Out:
# True

# %%
# checking that funded amount should be less than or equals to applied loan amount, by using the opposite condition output rows are zero
df[df.funded_amnt > df.loan_amnt].shape
# Out:
# (0, 111)

# %%
# checking that funded amount should be greater than or equals to funded amount by investor, and this is being tested by using the opposite condition where output rows should be zero
df[df.funded_amnt<df.funded_amnt_inv].shape
# Out:
# (0, 111)

# %%
# Term of the loan should be either 36 months or 60 months
# So, checking the unique values in the term column by grouping the same

df.term.groupby(by=df.term).describe()
# Out:
#         count  mean  std   min   25%   50%   75%   max
# term
# 36    29096.0  36.0  0.0  36.0  36.0  36.0  36.0  36.0
# 60    10621.0  60.0  0.0  60.0  60.0  60.0  60.0  60.0

# %%
df.int_rate.groupby(by=[df.grade, df.sub_grade, df.term]).describe()
# Out:
#                      count unique     top freq
# grade sub_grade term
# A     A1        36    1139      6   5.42%  573
#       A2        36    1494      7   5.79%  400
#                 60      14      2   5.79%   10
#       A3        36    1769      9   6.99%  336
#                 60      41      2   6.17%   31
#       A4        36    2753     12   7.49%  641
#                 60     133      5   6.54%   43
#       A5        36    2495     10   7.88%  641
#                 60     247      5   7.88%   84
# B     B1        36    1619     15   9.91%  329
#                 60     211      5  10.38%   55
#       B2        36    1724     15  10.65%  328
#                 60     333      5  10.65%  107
#       B3        36    2195     15  10.99%  525
#                 60     722      6  10.99%  194
#       B4        36    1819     13  11.49%  492
#                 60     693      6  11.49%  333
#       B5        36    1974     15  12.69%  334
#                 60     730      7  11.99%  204
# C     C1        36    1470     13  12.99%  256
#                 60     666      7  12.99%  187
#       C2        36    1341     14  14.27%  232
#                 60     670      7  13.49%  203
#       C3        36    1092     14  13.48%  152
#                 60     437      6  13.98%  132
#       C4        36     954     15  13.85%  130
#                 60     282      4  14.79%   93
#       C5        36     892     15  15.23%  125
#                 60     294      5  15.23%   90
# D     D1        36     918     15  15.62%  162
#                 60      13      5  15.62%    5
#       D2        36     816     13  14.96%  202
#                 60     532      8  15.99%  151
#       D3        36     637     14  16.49%  105
#                 60     536      6  17.27%  138
#       D4        36     494     13  15.65%  110
#                 60     487      7  16.89%  132
#       D5        36     366     14  16.00%   58
#                 60     508      8  17.49%  141
# E     E1        36     286     12  16.45%   70
#                 60     477      6  17.99%  118
#       E2        36     211     12  16.82%   41
#                 60     445      6  18.39%  126
#       E3        36     164     12  17.19%   32
#                 60     389      7  19.42%   98
#       E4        36     108     14  17.56%   26
#                 60     346      6  19.29%   94
#       E5        36      99     14  17.93%   30
#                 60     317      7  19.69%   96
# F     F1        36      62     10  18.30%   14
#                 60     267      6  20.25%   74
#       F2        36      54     11  18.43%   13
#                 60     195      6  20.62%   53
#       F3        36      31     10  19.04%   10
#                 60     154      5  20.99%   48
#       F4        36      38     10  19.13%   11
#                 60     130      6  21.36%   41
#       F5        36      26      8  19.47%    7
#                 60      92      6  21.74%   27
# G     G1        36      20      7  19.82%    5
#                 60      84      5  22.11%   28
#       G2        36      13      6  20.03%    4
#                 60      65      5  20.48%   21
#       G3        36       4      4  20.40%    1
#                 60      44      5  20.85%   15
#       G4        36       9      5  21.27%    3
#                 60      47      6  23.91%   11
#       G5        36      10      6  21.21%    4
#                 60      20      6  21.59%    7

# %%
df.emp_length.value_counts()
# Out:
# 10+ years    8879
# < 1 year     4583
# 2 years      4388
# 3 years      4095
# 4 years      3436
# 5 years      3282
# 1 year       3240
# 6 years      2229
# 7 years      1773
# 8 years      1479
# 9 years      1258
# Name: emp_length, dtype: int64

# %%
# Home ownership should be Mortage, Own, Rent and Other
df.home_ownership.value_counts()
# Out:
# RENT        18899
# MORTGAGE    17659
# OWN          3058
# OTHER          98
# NONE            3
# Name: home_ownership, dtype: int64

# %%
# In home ownership column we have None for home ownership, which shouldn't be there
# As there is no specific factor to determine the home ownership
pd.set_option('display.max_columns', 200)
df[df.home_ownership=='NONE']
# Out:
#            id member_id  loan_amnt  funded_amnt  funded_amnt_inv  term  \
# 39318  231321    214993      10000        10000          1228.06    36
# 39659  121568    121574       4000         4000          1925.00    36
# 39660  121535    121373       2800         2800          1625.00    36
#
#       int_rate  installment grade sub_grade emp_title emp_length  \
# 39318    7.75%       312.22     A        A3       ups    5 years
# 39659    9.64%       128.41     B        B4       NaN   < 1 year
# 39660    8.70%        88.65     B        B1       NaN   < 1 year
#
#       home_ownership  annual_inc verification_status    issue_d loan_status  \
# 39318           NONE     22200.0        Not Verified 2008-01-01  Fully Paid
# 39659           NONE    100000.0        Not Verified 2007-08-01  Fully Paid
# 39660           NONE    120000.0        Not Verified 2007-08-01  Fully Paid
#
#       pymnt_plan                                                url  \
# 39318          n  https://lendingclub.com/browse/loanDetail.acti...
# 39659          n  https://lendingclub.com/browse/loanDetail.acti...
# 39660          n  https://lendingclub.com/browse/loanDetail.acti...
#
#                                                     desc             purpose  \
# 39318  I plan to pay off my credit cards, leaving me ...  debt_consolidation
# 39659  I took a high interest loan from Citibank in 2...               other
# 39660  The family is expanding in October and we are ...               other
#
#                                 title zip_code addr_state    dti  delinq_2yrs  \
# 39318                 Melinda Holster    233xx         VA   5.24            0
# 39659  Refinancing high interest loan    950xx         CA  15.00            0
# 39660                  Baby is coming    024xx         MA  15.00            0
#
#       earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 39318       1994-04-01               0                     0.0
# 39659       1999-05-01               1                     NaN
# 39660       1999-05-01               1                     NaN
#
#        mths_since_last_record  open_acc  pub_rec  revol_bal  revol_util  \
# 39318                     0.0         9        0       4767         8.7
# 39659                     NaN         6        0       8155        14.9
# 39660                     NaN         6        0       8155        14.9
#
#        total_acc initial_list_status  out_prncp  out_prncp_inv   total_pymnt  \
# 39318         22                   f        0.0            0.0  11239.620890
# 39659          8                   f        0.0            0.0   4622.489229
# 39660          8                   f        0.0            0.0   3191.218575
#
#        total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 39318          1380.00          9999.99        1239.63                 0.0
# 39659          2224.58          4000.00         622.49                 0.0
# 39660          1852.05          2800.00         391.22                 0.0
#
#        recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 39318         0.0                      0.0   2011-02-01           313.59
# 39659         0.0                      0.0   2010-09-01           129.76
# 39660         0.0                      0.0   2010-09-01            89.80
#
#       next_pymnt_d last_credit_pull_d  collections_12_mths_ex_med  \
# 39318          NaT         2011-01-01                         0.0
# 39659          NaT         2007-08-01                         NaN
# 39660          NaT         2007-08-01                         NaN
#
#        mths_since_last_major_derog  policy_code application_type  \
# 39318                          NaN            1       INDIVIDUAL
# 39659                          NaN            1       INDIVIDUAL
# 39660                          NaN            1       INDIVIDUAL
#
#        annual_inc_joint  dti_joint  verification_status_joint  acc_now_delinq  \
# 39318               NaN        NaN                        NaN               0
# 39659               NaN        NaN                        NaN               0
# 39660               NaN        NaN                        NaN               0
#
#        tot_coll_amt  tot_cur_bal  open_acc_6m  open_il_6m  open_il_12m  \
# 39318           NaN          NaN          NaN         NaN          NaN
# 39659           NaN          NaN          NaN         NaN          NaN
# 39660           NaN          NaN          NaN         NaN          NaN
#
#        open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 39318          NaN                 NaN           NaN      NaN          NaN
# 39659          NaN                 NaN           NaN      NaN          NaN
# 39660          NaN                 NaN           NaN      NaN          NaN
#
#        open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  \
# 39318          NaN         NaN       NaN               NaN     NaN
# 39659          NaN         NaN       NaN               NaN     NaN
# 39660          NaN         NaN       NaN               NaN     NaN
#
#        total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  \
# 39318          NaN           NaN                   NaN          NaN
# 39659          NaN           NaN                   NaN          NaN
# 39660          NaN           NaN                   NaN          NaN
#
#        bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  \
# 39318             NaN      NaN                       0.0            0
# 39659             NaN      NaN                       NaN            0
# 39660             NaN      NaN                       NaN            0
#
#        mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  \
# 39318                 NaN                   NaN                    NaN
# 39659                 NaN                   NaN                    NaN
# 39660                 NaN                   NaN                    NaN
#
#        mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  \
# 39318             NaN       NaN                   NaN
# 39659             NaN       NaN                   NaN
# 39660             NaN       NaN                   NaN
#
#        mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 39318                       NaN                    NaN
# 39659                       NaN                    NaN
# 39660                       NaN                    NaN
#
#        mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 39318                             NaN                    NaN             NaN
# 39659                             NaN                    NaN             NaN
# 39660                             NaN                    NaN             NaN
#
#        num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 39318              NaN          NaN        NaN        NaN            NaN
# 39659              NaN          NaN        NaN        NaN            NaN
# 39660              NaN          NaN        NaN        NaN            NaN
#
#        num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 39318            NaN                  NaN       NaN               NaN
# 39659            NaN                  NaN       NaN               NaN
# 39660            NaN                  NaN       NaN               NaN
#
#        num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 39318           NaN                 NaN                 NaN             NaN
# 39659           NaN                 NaN                 NaN             NaN
# 39660           NaN                 NaN                 NaN             NaN
#
#        percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 39318               NaN                   NaN        0.0              NaN
# 39659               NaN                   NaN        NaN              NaN
# 39660               NaN                   NaN        NaN              NaN
#
#        total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit
# 39318                NaN             NaN                         NaN
# 39659                NaN             NaN                         NaN
# 39660                NaN             NaN                         NaN

# %%
# So, choosing OTHER as home ownership is wise in this situation
df.home_ownership = df.home_ownership.apply(lambda x: "OTHER" if x == "NONE" else x)

# again checking the home ownership column 
df.home_ownership.value_counts()
# Out:
# RENT        18899
# MORTGAGE    17659
# OWN          3058
# OTHER         101
# Name: home_ownership, dtype: int64

# %%
df.verification_status.value_counts(dropna=False)
# Out:
# Not Verified       16921
# Verified           12809
# Source Verified     9987
# Name: verification_status, dtype: int64

# %%
df.loan_status.value_counts(dropna=False)
# Out:
# Fully Paid     32950
# Charged Off     5627
# Current         1140
# Name: loan_status, dtype: int64

# %% [markdown]
# # Data Cleaning & Handling missing values
#
# ### Removing empty columns

# %%
# checking number of empty cells in a column
df.isnull().sum()
# Out:
# id                                    0
# member_id                             0
# loan_amnt                             0
# funded_amnt                           0
# funded_amnt_inv                       0
# term                                  0
# int_rate                              0
# installment                           0
# grade                                 0
# sub_grade                             0
# emp_title                          2459
# emp_length                         1075
# home_ownership                        0
# annual_inc                            0
# verification_status                   0
# issue_d                               0
# loan_status                           0
# pymnt_plan                            0
# url                                   0
# desc                              12940
# purpose                               0
# title                                11
# zip_code                              0
# addr_state                            0
# dti                                   0
# delinq_2yrs                           0
# earliest_cr_line                      0
# inq_last_6mths                        0
# mths_since_last_delinq            25682
# mths_since_last_record            36931
# open_acc                              0
# pub_rec                               0
# revol_bal                             0
# revol_util                           50
# total_acc                             0
# initial_list_status                   0
# out_prncp                             0
# out_prncp_inv                         0
# total_pymnt                           0
# total_pymnt_inv                       0
# total_rec_prncp                       0
# total_rec_int                         0
# total_rec_late_fee                    0
# recoveries                            0
# collection_recovery_fee               0
# last_pymnt_d                         71
# last_pymnt_amnt                       0
# next_pymnt_d                      38577
# last_credit_pull_d                    2
# collections_12_mths_ex_med           56
# mths_since_last_major_derog       39717
# policy_code                           0
# application_type                      0
# annual_inc_joint                  39717
# dti_joint                         39717
# verification_status_joint         39717
# acc_now_delinq                        0
# tot_coll_amt                      39717
# tot_cur_bal                       39717
# open_acc_6m                       39717
# open_il_6m                        39717
# open_il_12m                       39717
# open_il_24m                       39717
# mths_since_rcnt_il                39717
# total_bal_il                      39717
# il_util                           39717
# open_rv_12m                       39717
# open_rv_24m                       39717
# max_bal_bc                        39717
# all_util                          39717
# total_rev_hi_lim                  39717
# inq_fi                            39717
# total_cu_tl                       39717
# inq_last_12m                      39717
# acc_open_past_24mths              39717
# avg_cur_bal                       39717
# bc_open_to_buy                    39717
# bc_util                           39717
# chargeoff_within_12_mths             56
# delinq_amnt                           0
# mo_sin_old_il_acct                39717
# mo_sin_old_rev_tl_op              39717
# mo_sin_rcnt_rev_tl_op             39717
# mo_sin_rcnt_tl                    39717
# mort_acc                          39717
# mths_since_recent_bc              39717
# mths_since_recent_bc_dlq          39717
# mths_since_recent_inq             39717
# mths_since_recent_revol_delinq    39717
# num_accts_ever_120_pd             39717
# num_actv_bc_tl                    39717
# num_actv_rev_tl                   39717
# num_bc_sats                       39717
# num_bc_tl                         39717
# num_il_tl                         39717
# num_op_rev_tl                     39717
# num_rev_accts                     39717
# num_rev_tl_bal_gt_0               39717
# num_sats                          39717
# num_tl_120dpd_2m                  39717
# num_tl_30dpd                      39717
# num_tl_90g_dpd_24m                39717
# num_tl_op_past_12m                39717
# pct_tl_nvr_dlq                    39717
# percent_bc_gt_75                  39717
# pub_rec_bankruptcies                697
# tax_liens                            39
# tot_hi_cred_lim                   39717
# total_bal_ex_mort                 39717
# total_bc_limit                    39717
# total_il_high_credit_limit        39717
# dtype: int64

# %%
# There are total of 39717 records in the dataset
# if we abserved above data which consist of number of null values in a column
# we can see that some of the columns are completely empty, which are not usable for analysis, so dropping the column
df = df.dropna(axis=1, how='all')
df.shape
# Out:
# (39717, 57)

# %%
# dropping columns with huge missing records
df = df.drop(axis=1, columns=['next_pymnt_d', 'mths_since_last_delinq', 'mths_since_last_record', 'next_pymnt_d'])
df.shape
# Out:
# (39717, 54)

# %% [markdown]
# ### Checking single value column in the dataset which are not usable in Analysis

# %%
df.pymnt_plan.value_counts(dropna=False)
# Out:
# n    39717
# Name: pymnt_plan, dtype: int64

# %%
df.initial_list_status.value_counts(dropna=False)
# Out:
# f    39717
# Name: initial_list_status, dtype: int64

# %%
df.collections_12_mths_ex_med.value_counts(dropna=False)
# Out:
# 0.0    39661
# NaN       56
# Name: collections_12_mths_ex_med, dtype: int64

# %%
df.policy_code.value_counts(dropna=False)
# Out:
# 1    39717
# Name: policy_code, dtype: int64

# %%
df.acc_now_delinq.value_counts(dropna=False)
# Out:
# 0    39717
# Name: acc_now_delinq, dtype: int64

# %%
df.chargeoff_within_12_mths.value_counts(dropna=False)
# Out:
# 0.0    39661
# NaN       56
# Name: chargeoff_within_12_mths, dtype: int64

# %%
df.delinq_amnt.value_counts(dropna=False)
# Out:
# 0    39717
# Name: delinq_amnt, dtype: int64

# %%
df.tax_liens.value_counts(dropna=False)
# Out:
# 0.0    39678
# NaN       39
# Name: tax_liens, dtype: int64

# %%
df.application_type.value_counts(dropna=False)
# Out:
# INDIVIDUAL    39717
# Name: application_type, dtype: int64

# %%
df = df.drop(axis=1, columns=['pymnt_plan', 'initial_list_status', 'collections_12_mths_ex_med', 'policy_code', 
                              'acc_now_delinq', 'chargeoff_within_12_mths', 'delinq_amnt', 'tax_liens', 'application_type'])
df.shape
# Out:
# (39717, 45)

# %%
df.isnull().sum()
# Out:
# id                             0
# member_id                      0
# loan_amnt                      0
# funded_amnt                    0
# funded_amnt_inv                0
# term                           0
# int_rate                       0
# installment                    0
# grade                          0
# sub_grade                      0
# emp_title                   2459
# emp_length                  1075
# home_ownership                 0
# annual_inc                     0
# verification_status            0
# issue_d                        0
# loan_status                    0
# url                            0
# desc                       12940
# purpose                        0
# title                         11
# zip_code                       0
# addr_state                     0
# dti                            0
# delinq_2yrs                    0
# earliest_cr_line               0
# inq_last_6mths                 0
# open_acc                       0
# pub_rec                        0
# revol_bal                      0
# revol_util                    50
# total_acc                      0
# out_prncp                      0
# out_prncp_inv                  0
# total_pymnt                    0
# total_pymnt_inv                0
# total_rec_prncp                0
# total_rec_int                  0
# total_rec_late_fee             0
# recoveries                     0
# collection_recovery_fee        0
# last_pymnt_d                  71
# last_pymnt_amnt                0
# last_credit_pull_d             2
# pub_rec_bankruptcies         697
# dtype: int64

# %%
df.emp_title.describe()
# Out:
# count       37258
# unique      28820
# top       US Army
# freq          134
# Name: emp_title, dtype: object

# %%
# Filling missing emp_title as Others
df.emp_title = df.emp_title.fillna("Others")
df.emp_title.isnull().sum()
# Out:
# 0

# %%
df.emp_length.value_counts(dropna=False)
# Out:
# 10+ years    8879
# < 1 year     4583
# 2 years      4388
# 3 years      4095
# 4 years      3436
# 5 years      3282
# 1 year       3240
# 6 years      2229
# 7 years      1773
# 8 years      1479
# 9 years      1258
# NaN          1075
# Name: emp_length, dtype: int64

# %%
df.desc.isnull().sum()
# Out:
# 12940

# %%
df.desc = df.desc.fillna("Others")
df.desc.isnull().sum()
# Out:
# 0

# %%
df = df[~df.title.isnull()]

# %%
# Number of public record bankruptcies field is an affective field for analysis
df.pub_rec_bankruptcies.value_counts(dropna=False)
# Out:
# 0.0    37328
# 1.0     1674
# NaN      697
# 2.0        7
# Name: pub_rec_bankruptcies, dtype: int64

# %%
# Only 697 missing record, so dropping the empty records
df = df[~df.pub_rec_bankruptcies.isnull()]
df.pub_rec_bankruptcies.value_counts(dropna=False)
# Out:
# 0.0    37328
# 1.0     1674
# 2.0        7
# Name: pub_rec_bankruptcies, dtype: int64

# %%
df.revol_util.isnull().sum()
# Out:
# 50

# %%
df = df[~df.revol_util.isnull()]
df.revol_util.isnull().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (38959, 45)

# %%
df.last_pymnt_d.describe()
# Out:
# count                   38892
# unique                     97
# top       2016-05-01 00:00:00
# freq                     1256
# first     2008-05-01 00:00:00
# last      2016-05-01 00:00:00
# Name: last_pymnt_d, dtype: object

# %%
df = df[~(df.last_pymnt_d.isnull() | df.last_credit_pull_d.isnull())]
df.shape
# Out:
# (38891, 45)

# %%
df = df[~df.emp_length.isnull()]
df.isnull().sum()
# Out:
# id                         0
# member_id                  0
# loan_amnt                  0
# funded_amnt                0
# funded_amnt_inv            0
# term                       0
# int_rate                   0
# installment                0
# grade                      0
# sub_grade                  0
# emp_title                  0
# emp_length                 0
# home_ownership             0
# annual_inc                 0
# verification_status        0
# issue_d                    0
# loan_status                0
# url                        0
# desc                       0
# purpose                    0
# title                      0
# zip_code                   0
# addr_state                 0
# dti                        0
# delinq_2yrs                0
# earliest_cr_line           0
# inq_last_6mths             0
# open_acc                   0
# pub_rec                    0
# revol_bal                  0
# revol_util                 0
# total_acc                  0
# out_prncp                  0
# out_prncp_inv              0
# total_pymnt                0
# total_pymnt_inv            0
# total_rec_prncp            0
# total_rec_int              0
# total_rec_late_fee         0
# recoveries                 0
# collection_recovery_fee    0
# last_pymnt_d               0
# last_pymnt_amnt            0
# last_credit_pull_d         0
# pub_rec_bankruptcies       0
# dtype: int64

# %%
df.head(20)
# Out:
#          id member_id  loan_amnt  funded_amnt  funded_amnt_inv  term int_rate  \
# 0   1077501   1296599       5000         5000           4975.0    36   10.65%
# 1   1077430   1314167       2500         2500           2500.0    60   15.27%
# 2   1077175   1313524       2400         2400           2400.0    36   15.96%
# 3   1076863   1277178      10000        10000          10000.0    36   13.49%
# 4   1075358   1311748       3000         3000           3000.0    60   12.69%
# 5   1075269   1311441       5000         5000           5000.0    36    7.90%
# 6   1069639   1304742       7000         7000           7000.0    60   15.96%
# 7   1072053   1288686       3000         3000           3000.0    36   18.64%
# 8   1071795   1306957       5600         5600           5600.0    60   21.28%
# 9   1071570   1306721       5375         5375           5350.0    60   12.69%
# 10  1070078   1305201       6500         6500           6500.0    60   14.65%
# 11  1069908   1305008      12000        12000          12000.0    36   12.69%
# 12  1064687   1298717       9000         9000           9000.0    36   13.49%
# 13  1069866   1304956       3000         3000           3000.0    36    9.91%
# 14  1069057   1303503      10000        10000          10000.0    36   10.65%
# 15  1069759   1304871       1000         1000           1000.0    36   16.29%
# 16  1065775   1299699      10000        10000          10000.0    36   15.27%
# 17  1069971   1304884       3600         3600           3600.0    36    6.03%
# 18  1062474   1294539       6000         6000           6000.0    36   11.71%
# 19  1069742   1304855       9200         9200           9200.0    36    6.03%
#
#     installment grade sub_grade                            emp_title  \
# 0        162.87     B        B2                               Others
# 1         59.83     C        C4                                Ryder
# 2         84.33     C        C5                               Others
# 3        339.31     C        C1                  AIR RESOURCES BOARD
# 4         67.79     B        B5             University Medical Group
# 5        156.46     A        A4                 Veolia Transportaton
# 6        170.08     C        C5            Southern Star Photography
# 7        109.43     E        E1                      MKC Accounting
# 8        152.39     F        F2                               Others
# 9        121.45     B        B5                            Starbucks
# 10       153.45     C        C3                Southwest Rural metro
# 11       402.54     B        B5                                 UCLA
# 12       305.38     C        C1  Va. Dept of Conservation/Recreation
# 13        96.68     B        B1                               Target
# 14       325.74     B        B2                                SFMTA
# 15        35.31     D        D1             Internal revenue Service
# 16       347.98     C        C4                    Chin's Restaurant
# 17       109.57     A        A1                             Duracell
# 18       198.46     B        B3                Connection Inspection
# 19       280.01     A        A1         Network Interpreting Service
#
#    emp_length home_ownership  annual_inc verification_status    issue_d  \
# 0   10+ years           RENT    24000.00            Verified 2011-12-01
# 1    < 1 year           RENT    30000.00     Source Verified 2011-12-01
# 2   10+ years           RENT    12252.00        Not Verified 2011-12-01
# 3   10+ years           RENT    49200.00     Source Verified 2011-12-01
# 4      1 year           RENT    80000.00     Source Verified 2011-12-01
# 5     3 years           RENT    36000.00     Source Verified 2011-12-01
# 6     8 years           RENT    47004.00        Not Verified 2011-12-01
# 7     9 years           RENT    48000.00     Source Verified 2011-12-01
# 8     4 years            OWN    40000.00     Source Verified 2011-12-01
# 9    < 1 year           RENT    15000.00            Verified 2011-12-01
# 10    5 years            OWN    72000.00        Not Verified 2011-12-01
# 11  10+ years            OWN    75000.00     Source Verified 2011-12-01
# 12   < 1 year           RENT    30000.00     Source Verified 2011-12-01
# 13    3 years           RENT    15000.00     Source Verified 2011-12-01
# 14    3 years           RENT   100000.00     Source Verified 2011-12-01
# 15   < 1 year           RENT    28000.00        Not Verified 2011-12-01
# 16    4 years           RENT    42000.00        Not Verified 2011-12-01
# 17  10+ years       MORTGAGE   110000.00        Not Verified 2011-12-01
# 18     1 year       MORTGAGE    84000.00            Verified 2011-12-01
# 19    6 years           RENT    77385.19        Not Verified 2011-12-01
#
#     loan_status                                                url  \
# 0    Fully Paid  https://lendingclub.com/browse/loanDetail.acti...
# 1   Charged Off  https://lendingclub.com/browse/loanDetail.acti...
# 2    Fully Paid  https://lendingclub.com/browse/loanDetail.acti...
# 3    Fully Paid  https://lendingclub.com/browse/loanDetail.acti...
# 4       Current  https://lendingclub.com/browse/loanDetail.acti...
# 5    Fully Paid  https://lendingclub.com/browse/loanDetail.acti...
# 6    Fully Paid  https://lendingclub.com/browse/loanDetail.acti...
# 7    Fully Paid  https://lendingclub.com/browse/loanDetail.acti...
# 8   Charged Off  https://lendingclub.com/browse/loanDetail.acti...
# 9   Charged Off  https://lendingclub.com/browse/loanDetail.acti...
# 10   Fully Paid  https://lendingclub.com/browse/loanDetail.acti...
# 11   Fully Paid  https://lendingclub.com/browse/loanDetail.acti...
# 12  Charged Off  https://lendingclub.com/browse/loanDetail.acti...
# 13   Fully Paid  https://lendingclub.com/browse/loanDetail.acti...
# 14  Charged Off  https://lendingclub.com/browse/loanDetail.acti...
# 15   Fully Paid  https://lendingclub.com/browse/loanDetail.acti...
# 16   Fully Paid  https://lendingclub.com/browse/loanDetail.acti...
# 17   Fully Paid  https://lendingclub.com/browse/loanDetail.acti...
# 18   Fully Paid  https://lendingclub.com/browse/loanDetail.acti...
# 19   Fully Paid  https://lendingclub.com/browse/loanDetail.acti...
#
#                                                  desc             purpose  \
# 0     Borrower added on 12/22/11 > I need to upgra...         credit_card
# 1     Borrower added on 12/22/11 > I plan to use t...                 car
# 2                                              Others      small_business
# 3     Borrower added on 12/21/11 > to pay for prop...               other
# 4     Borrower added on 12/21/11 > I plan on combi...               other
# 5                                              Others             wedding
# 6     Borrower added on 12/18/11 > I am planning o...  debt_consolidation
# 7     Borrower added on 12/16/11 > Downpayment for...                 car
# 8     Borrower added on 12/21/11 > I own a small h...      small_business
# 9     Borrower added on 12/16/11 > I'm trying to b...               other
# 10    Borrower added on 12/15/11 > I had recived a...  debt_consolidation
# 11                                             Others  debt_consolidation
# 12    Borrower added on 12/15/11 > Plan to pay off...  debt_consolidation
# 13    Borrower added on 12/19/11 > I intend to pay...         credit_card
# 14                                             Others               other
# 15                                             Others  debt_consolidation
# 16                                             Others    home_improvement
# 17    Borrower added on 12/15/11 > Payoff other le...      major_purchase
# 18    Borrower added on 12/16/11 > This is a loan ...             medical
# 19                                             Others  debt_consolidation
#
#                                     title zip_code addr_state    dti  \
# 0                                Computer    860xx         AZ  27.65
# 1                                    bike    309xx         GA   1.00
# 2                    real estate business    606xx         IL   8.72
# 3                                personel    917xx         CA  20.00
# 4                                Personal    972xx         OR  17.94
# 5   My wedding loan I promise to pay back    852xx         AZ  11.20
# 6                                    Loan    280xx         NC  23.51
# 7                         Car Downpayment    900xx         CA   5.35
# 8    Expand Business & Buy Debt Portfolio    958xx         CA   5.55
# 9             Building my credit history.    774xx         TX  18.08
# 10             High intrest Consolidation    853xx         AZ  16.12
# 11                          Consolidation    913xx         CA  10.78
# 12                                freedom    245xx         VA  10.08
# 13                          citicard fund    606xx         IL  12.56
# 14                             Other Loan    951xx         CA   7.06
# 15                Debt Consolidation Loan    641xx         MO  20.31
# 16                                   Home    921xx         CA  18.60
# 17                                Holiday    067xx         CT  10.52
# 18                                Medical    890xx         UT  18.44
# 19    lowerratemeanseasiertogetoutofdebt!    921xx         CA   9.86
#
#     delinq_2yrs earliest_cr_line  inq_last_6mths  open_acc  pub_rec  \
# 0             0       1985-01-01               1         3        0
# 1             0       1999-04-01               5         3        0
# 2             0       2001-11-01               2         2        0
# 3             0       1996-02-01               1        10        0
# 4             0       1996-01-01               0        15        0
# 5             0       2004-11-01               3         9        0
# 6             0       2005-07-01               1         7        0
# 7             0       2007-01-01               2         4        0
# 8             0       2004-04-01               2        11        0
# 9             0       2004-09-01               0         2        0
# 10            0       1998-01-01               2        14        0
# 11            0       1989-10-01               0        12        0
# 12            0       2004-04-01               1         4        0
# 13            0       2003-07-01               2        11        0
# 14            0       1991-05-01               2        14        0
# 15            0       2007-09-01               1        11        0
# 16            0       1998-10-01               2        14        0
# 17            0       1993-08-01               0        20        0
# 18            2       2003-10-01               0         4        0
# 19            0       2001-01-01               0         8        0
#
#     revol_bal  revol_util  total_acc  out_prncp  out_prncp_inv   total_pymnt  \
# 0       13648       83.70          9       0.00           0.00   5863.155187
# 1        1687        9.40          4       0.00           0.00   1008.710000
# 2        2956       98.50         10       0.00           0.00   3005.666844
# 3        5598       21.00         37       0.00           0.00  12231.890000
# 4       27783       53.90         38     524.06         524.06   3513.330000
# 5        7963       28.30         12       0.00           0.00   5632.210000
# 6       17726       85.60         11       0.00           0.00  10110.840000
# 7        8221       87.50          4       0.00           0.00   3939.135294
# 8        5210       32.60         13       0.00           0.00    646.020000
# 9        9279       36.50          3       0.00           0.00   1476.190000
# 10       4032       20.60         23       0.00           0.00   7678.017673
# 11      23336       67.10         34       0.00           0.00  13947.989160
# 12      10452       91.70          9       0.00           0.00   2270.700000
# 13       7323       43.10         11       0.00           0.00   3480.269999
# 14      11997       55.50         29       0.00           0.00   7471.990000
# 15       6524       81.50         23       0.00           0.00   1270.716942
# 16      24043       70.20         28       0.00           0.00  12527.150000
# 17      22836       16.00         42       0.00           0.00   3785.271965
# 18          0       37.73         14       0.00           0.00   7167.072893
# 19       7314       23.10         28       0.00           0.00   9460.000848
#
#     total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 0           5833.84          5000.00         863.16                0.00
# 1           1008.71           456.46         435.17                0.00
# 2           3005.67          2400.00         605.67                0.00
# 3          12231.89         10000.00        2214.92               16.97
# 4           3513.33          2475.94        1037.39                0.00
# 5           5632.21          5000.00         632.21                0.00
# 6          10110.84          6985.61        3125.23                0.00
# 7           3939.14          3000.00         939.14                0.00
# 8            646.02           162.02         294.94                0.00
# 9           1469.34           673.48         533.42                0.00
# 10          7678.02          6500.00        1178.02                0.00
# 11         13947.99         12000.00        1947.99                0.00
# 12          2270.70          1256.14         570.26                0.00
# 13          3480.27          3000.00         480.27                0.00
# 14          7471.99          5433.47        1393.42                0.00
# 15          1270.72          1000.00         270.72                0.00
# 16         12527.15         10000.00        2527.15                0.00
# 17          3785.27          3600.00         185.27                0.00
# 18          7167.07          6000.00        1152.07               15.00
# 19          9460.00          9200.00         260.00                0.00
#
#     recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 0         0.00                   0.0000   2015-01-01           171.62
# 1       117.08                   1.1100   2013-04-01           119.66
# 2         0.00                   0.0000   2014-06-01           649.91
# 3         0.00                   0.0000   2015-01-01           357.48
# 4         0.00                   0.0000   2016-05-01            67.79
# 5         0.00                   0.0000   2015-01-01           161.03
# 6         0.00                   0.0000   2016-05-01          1313.76
# 7         0.00                   0.0000   2015-01-01           111.34
# 8       189.06                   2.0900   2012-04-01           152.39
# 9       269.29                   2.5200   2012-11-01           121.45
# 10        0.00                   0.0000   2013-06-01          1655.54
# 11        0.00                   0.0000   2013-09-01          6315.30
# 12      444.30                   4.1600   2012-07-01           305.38
# 13        0.00                   0.0000   2015-01-01           102.43
# 14      645.10                   6.3145   2013-10-01           325.74
# 15        0.00                   0.0000   2015-01-01            36.32
# 16        0.00                   0.0000   2015-01-01           370.46
# 17        0.00                   0.0000   2013-05-01           583.45
# 18        0.00                   0.0000   2015-02-01            16.98
# 19        0.00                   0.0000   2012-07-01          8061.10
#
#    last_credit_pull_d  pub_rec_bankruptcies
# 0          2016-05-01                   0.0
# 1          2013-09-01                   0.0
# 2          2016-05-01                   0.0
# 3          2016-04-01                   0.0
# 4          2016-05-01                   0.0
# 5          2016-01-01                   0.0
# 6          2016-05-01                   0.0
# 7          2014-12-01                   0.0
# 8          2012-08-01                   0.0
# 9          2013-03-01                   0.0
# 10         2015-12-01                   0.0
# 11         2013-08-01                   0.0
# 12         2012-11-01                   0.0
# 13         2016-05-01                   0.0
# 14         2014-03-01                   0.0
# 15         2016-05-01                   0.0
# 16         2015-04-01                   0.0
# 17         2014-05-01                   0.0
# 18         2015-07-01                   0.0
# 19         2016-02-01                   0.0

# %% [markdown]
# # Feature Analysis
# After data cleaning, in this step we are trying understand how feature are behaving that influences in business decision making

# %%
# To check datatype of each attribute after data cleaning
df.info() #shows datatype of each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37825 entries, 0 to 39680
# Data columns (total 45 columns):
# id                         37825 non-null object
# member_id                  37825 non-null object
# loan_amnt                  37825 non-null int64
# funded_amnt                37825 non-null int64
# funded_amnt_inv            37825 non-null float64
# term                       37825 non-null int64
# int_rate                   37825 non-null object
# installment                37825 non-null float64
# grade                      37825 non-null object
# sub_grade                  37825 non-null object
# emp_title                  37825 non-null object
# emp_length                 37825 non-null object
# home_ownership             37825 non-null object
# annual_inc                 37825 non-null float64
# verification_status        37825 non-null object
# issue_d                    37825 non-null datetime64[ns]
# loan_status                37825 non-null object
# url                        37825 non-null object
# desc                       37825 non-null object
# purpose                    37825 non-null object
# title                      37825 non-null object
# zip_code                   37825 non-null object
# addr_state                 37825 non-null object
# dti                        37825 non-null float64
# delinq_2yrs                37825 non-null int64
# earliest_cr_line           37825 non-null datetime64[ns]
# inq_last_6mths             37825 non-null int64
# open_acc                   37825 non-null int64
# pub_rec                    37825 non-null int64
# revol_bal                  37825 non-null int64
# revol_util                 37825 non-null float64
# total_acc                  37825 non-null int64
# out_prncp                  37825 non-null float64
# out_prncp_inv              37825 non-null float64
# total_pymnt                37825 non-null float64
# total_pymnt_inv            37825 non-null float64
# total_rec_prncp            37825 non-null float64
# total_rec_int              37825 non-null float64
# total_rec_late_fee         37825 non-null float64
# recoveries                 37825 non-null float64
# collection_recovery_fee    37825 non-null float64
# last_pymnt_d               37825 non-null datetime64[ns]
# last_pymnt_amnt            37825 non-null float64
# last_credit_pull_d         37825 non-null datetime64[ns]
# pub_rec_bankruptcies       37825 non-null float64
# dtypes: datetime64[ns](4), float64(16), int64(9), object(16)
# memory usage: 13.3+ MB

# %%
# To confirm if all null values are cleared in data cleaning step
df.isna().sum()
# Out:
# id                         0
# member_id                  0
# loan_amnt                  0
# funded_amnt                0
# funded_amnt_inv            0
# term                       0
# int_rate                   0
# installment                0
# grade                      0
# sub_grade                  0
# emp_title                  0
# emp_length                 0
# home_ownership             0
# annual_inc                 0
# verification_status        0
# issue_d                    0
# loan_status                0
# url                        0
# desc                       0
# purpose                    0
# title                      0
# zip_code                   0
# addr_state                 0
# dti                        0
# delinq_2yrs                0
# earliest_cr_line           0
# inq_last_6mths             0
# open_acc                   0
# pub_rec                    0
# revol_bal                  0
# revol_util                 0
# total_acc                  0
# out_prncp                  0
# out_prncp_inv              0
# total_pymnt                0
# total_pymnt_inv            0
# total_rec_prncp            0
# total_rec_int              0
# total_rec_late_fee         0
# recoveries                 0
# collection_recovery_fee    0
# last_pymnt_d               0
# last_pymnt_amnt            0
# last_credit_pull_d         0
# pub_rec_bankruptcies       0
# dtype: int64

# %%
#To Analyze basic metrics have used df.describe() and have taken transpose of it.
df.describe().T
# Out:
#                            count          mean           std      min  \
# loan_amnt                37825.0  11328.779907   7477.278024   500.00
# funded_amnt              37825.0  11050.900198   7205.116525   500.00
# funded_amnt_inv          37825.0  10618.933508   7113.288445     0.00
# term                     37825.0     42.556933     10.694674    36.00
# installment              37825.0    327.159748    209.098068    16.08
# annual_inc               37825.0  69675.598521  63650.153633  4000.00
# dti                      37825.0     13.377813      6.655779     0.00
# delinq_2yrs              37825.0      0.145803      0.490522     0.00
# inq_last_6mths           37825.0      0.866728      1.066541     0.00
# open_acc                 37825.0      9.325235      4.375127     2.00
# pub_rec                  37825.0      0.053721      0.234775     0.00
# revol_bal                37825.0  13482.271408  15878.604047     0.00
# revol_util               37825.0     49.128863     28.276118     0.00
# total_acc                37825.0     22.200317     11.382984     2.00
# out_prncp                37825.0     52.335744    380.568286     0.00
# out_prncp_inv            37825.0     52.086627    379.177129     0.00
# total_pymnt              37825.0  12311.524402   9083.414899    33.73
# total_pymnt_inv          37825.0  11841.635927   8947.177493     0.00
# total_rec_prncp          37825.0   9913.439277   7089.585227     0.00
# total_rec_int            37825.0   2302.172673   2633.713963     6.22
# total_rec_late_fee       37825.0      1.334818      7.179826     0.00
# recoveries               37825.0     94.577719    690.467641     0.00
# collection_recovery_fee  37825.0     12.136395    148.128622     0.00
# last_pymnt_amnt          37825.0   2730.904205   4489.990231     0.01
# pub_rec_bankruptcies     37825.0      0.041507      0.200388     0.00
#
#                                   25%       50%          75%           max
# loan_amnt                 5600.000000  10000.00  15000.00000  3.500000e+04
# funded_amnt               5500.000000  10000.00  15000.00000  3.500000e+04
# funded_amnt_inv           5000.000000   9200.00  14608.70979  3.500000e+04
# term                        36.000000     36.00     60.00000  6.000000e+01
# installment                168.740000    283.20    434.75000  1.305190e+03
# annual_inc               41900.000000  60000.00  83500.00000  6.000000e+06
# dti                          8.270000     13.47     18.63000  2.999000e+01
# delinq_2yrs                  0.000000      0.00      0.00000  1.100000e+01
# inq_last_6mths               0.000000      1.00      1.00000  8.000000e+00
# open_acc                     6.000000      9.00     12.00000  4.400000e+01
# pub_rec                      0.000000      0.00      0.00000  4.000000e+00
# revol_bal                 3792.000000   8979.00  17186.00000  1.495880e+05
# revol_util                  25.800000     49.70     72.60000  9.990000e+01
# total_acc                   14.000000     21.00     29.00000  9.000000e+01
# out_prncp                    0.000000      0.00      0.00000  6.311470e+03
# out_prncp_inv                0.000000      0.00      0.00000  6.307370e+03
# total_pymnt               5647.319201  10074.70  16717.65424  5.856368e+04
# total_pymnt_inv           5387.750000   9611.84  16108.82000  5.856368e+04
# total_rec_prncp           4800.000000   8002.29  14000.00000  3.500002e+04
# total_rec_int              677.120000   1376.35   2889.12000  2.356368e+04
# total_rec_late_fee           0.000000      0.00      0.00000  1.802000e+02
# recoveries                   0.000000      0.00      0.00000  2.962335e+04
# collection_recovery_fee      0.000000      0.00      0.00000  7.002190e+03
# last_pymnt_amnt            224.800000    563.55   3402.61000  3.611520e+04
# pub_rec_bankruptcies         0.000000      0.00      0.00000  2.000000e+00

# %%
#To check behaviour of all features influencing on loan sanction have used box plot

dig, ax = plt.subplots(4, 3)
# Setting height and width of subplots
dig.set_figheight(15)
dig.set_figwidth(30)
# Adding spacing between boxes
dig.tight_layout(h_pad=True, w_pad=True)

#plotting of box plot
sns.boxplot(df["loan_amnt"], ax=ax[0, 0])
sns.boxplot(df["funded_amnt"], ax=ax[0, 1])
sns.boxplot(df["funded_amnt_inv"], ax=ax[0, 2])
sns.boxplot(df["installment"], ax=ax[1, 0])
sns.boxplot(df["annual_inc"], ax=ax[1, 1])
sns.boxplot(df["total_acc"], ax=ax[1, 2])
sns.boxplot(df["total_pymnt"], ax=ax[2, 0])
sns.boxplot(df["recoveries"], ax=ax[2, 1])
sns.boxplot(df["last_pymnt_amnt"], ax=ax[2, 2])
sns.boxplot(df["pub_rec_bankruptcies"], ax=ax[3, 0])
sns.boxplot(df["out_prncp"], ax=ax[3, 1])
sns.boxplot(df["collection_recovery_fee"], ax=ax[3, 2])
plt.show()

# %%
#To check behaviour of all features influencing on loan sanction have used scatter plot to understand better
dg, ax = plt.subplots(4, 3)
# Setting height and width of subplots
dg.set_figheight(15)
dg.set_figwidth(30)
# Adding spacing between boxes
dg.tight_layout(h_pad=True, w_pad=True)

sns.scatterplot(data=df["loan_amnt"], ax=ax[0, 0])
sns.scatterplot(data=df["funded_amnt"], ax=ax[0, 1])
sns.scatterplot(data=df["funded_amnt_inv"], ax=ax[0, 2])
sns.scatterplot(data=df["installment"], ax=ax[1, 0])
sns.scatterplot(data=df["annual_inc"], ax=ax[1, 1])
sns.scatterplot(data=df["total_acc"], ax=ax[1, 2])
sns.scatterplot(data=df["total_pymnt"], ax=ax[2, 0])
sns.scatterplot(data=df["recoveries"], ax=ax[2, 1])
sns.scatterplot(data=df["last_pymnt_amnt"], ax=ax[2, 2])
sns.scatterplot(data=df["pub_rec_bankruptcies"], ax=ax[3, 0])
sns.scatterplot(data=df["out_prncp"], ax=ax[3, 1])
sns.scatterplot(data=df["collection_recovery_fee"], ax=ax[3, 2])
plt.show()

# %%
#Have also plotted correlation matrix to understand how one variable is influencial to another
sns.heatmap(df.corr())
